# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import nltk
import time
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer  
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
micro = pd.read_csv('microwave.tsv', sep='\t')
hair = pd.read_csv('hair_dryer.tsv', sep='\t')
pacf = pd.read_csv('hair_dryer.tsv', sep='\t')

# %%
hair.head()
# Out:
#   marketplace  customer_id       review_id  product_id  product_parent  \
# 0          US     34678741   R9T1FE2ZX2X04  B003V264WW       732252283
# 1          US     11599505   RE36JAD5V53PO  B0009XH6V4       670161917
# 2          US      2282190   RIDHM8B7SCCV3  B0007NZPY6        16483457
# 3          US     43669858  R14QGWPCHU9LSE  B00BB8ZIW0       253917972
# 4          US       107098  R35BHQJHXXJD59  B003V264WW       732252283
#
#                                        product_title product_category  \
# 0  remington ac2015 t|studio salon collection pea...           Beauty
# 1                       andis micro turbo hair dryer           Beauty
# 2                              conair pro hair dryer           Beauty
# 3     remington silk ceramic professional hair dryer           Beauty
# 4  remington ac2015 t|studio salon collection pea...           Beauty
#
#    star_rating  helpful_votes  total_votes vine verified_purchase  \
# 0            5              0            0    N                 Y
# 1            4              0            0    N                 Y
# 2            5              0            1    N                 Y
# 3            5              0            0    N                 Y
# 4            4              0            0    N                 N
#
#                                      review_headline  \
# 0                                        Works great
# 1  I love travel blow dryers because they are eas...
# 2                                         Five Stars
# 3                                         Five Stars
# 4        I think's great. The cord length is perfect
#
#                                          review_body review_date
# 0                                       Works great!   8/31/2015
# 1  This dries my hair faster that bigger, more po...   8/31/2015
# 2                                   Love this dryer!   8/31/2015
# 3                              styling hair in style   8/31/2015
# 4  I just got this last week. I think's great. Th...   8/31/2015

# %% [markdown]
# ### 可视化星级与字符串长度的关系

# %%
df = pd.DataFrame(columns=['x', 'y'])
for i in range(5):
    a = micro[micro['star_rating']==(i+1)]
    length = a['review_body'].apply(len)
    k = pd.DataFrame({'x':i+1,
                      'y':length})
    df = pd.concat([df, k], axis=0)

# %%
#可视化
plt.scatter(df['x'], df['y'],  )

# %% [markdown]
# ### tfidf线性回归

# %%
# new_hair_cut = []#存储每个顾客评价的分词
# for i in range(11471):
#     k = hair_cut[hair_cut['line']==i]#line相同的df
#     k = k['word'].tolist()
#     if len(k) != 0:
#         new_hair_cut.append(k)
# print(len(new_hair_cut))
# print(len(set(hair_cut['line'])))

# %%
# index = set(hair_cut['line'])#索引相同index的score
# index = [i-1 for i in index]
# score = hair.loc[index, ['star_rating']]
# score = score['star_rating'].tolist()#为了便于读取数据
# hair_cut = pd.DataFrame({'score':score,
#                          'word':new_hair_cut})

# %%
# hair_train = hair.iloc[:10000, :]
# hair_test = hair.iloc[10000:, :]
# hair_score_train = hair.loc[:10000, 'star_rating']
# hair_score_test = hair.loc[10000:, 'star_rating']
# hair_score_train = np.array(hair_score_train).reshape(-1, 1)
# hair_score_test = np.array(hair_score_test).reshape(-1, 1)

# %% [markdown]
# #### 训练集：测试集=10000:1470

# %%
hair_cut = pd.read_csv('hair_dryer_line_seperate_words.csv')
ncr = pd.read_csv('nrc.csv')

# %%
corpus = hair['review_body'].tolist()
#将文本中的词语转换为词频矩阵  
vectorizer = CountVectorizer()  
#计算个词语出现的次数  
X = vectorizer.fit_transform(corpus)  
#获取词袋中所有文本关键词  
word = vectorizer.get_feature_names()  
transformer = TfidfTransformer()  
print(transformer)  
#将词频矩阵X统计成TF-IDF值  
tfidf = transformer.fit_transform(X)
# Out:
# TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True)

# %%
#建立所有词汇的tf-idf矩阵
tfidf = tfidf.toarray()
tfidf = pd.DataFrame(tfidf, columns=word)
hair_score = hair['star_rating']
ths = pd.concat([hair_score, tfidf], axis=1)

# %%
#删除全部为0的列
# n = 0
# a = {0}
# valid_word = []
# for i in word:
#     if set(tfidf[:, n])!=a:
#         valid_word.append(n)
#     n = n + 1

# %%
#建立只有情感词汇的tf-idf矩阵，删除横轴为空的向量；
ncr = [i for i in word if i in ncr]
ncr.append('star_rating')
ths = ths.loc[:, ncr]
dropall = ths.loc[~(ths==0).all(axis=1), :]

# %%
#清洗发现每个纵轴都有非零数据
ncr.remove('star_rating')
tfidf_train = np.array(ths.loc[0:8000, ncr])
tfidf_test = np.array(ths.loc[8000:, ncr])
tfidf_score_train = np.array(ths.loc[0:8000, 'star_rating'])
tfidf_score_test = np.array(ths.loc[8000:, 'star_rating'])
# n = 0
# a = {0}
# valid_word = []
# old_world = droprow.columns
# for i in old_world:
#     if set(droprow.iloc[:, n])!=a:
#         valid_word.append(i)
#     n = n + 1
# dropall = droprow.loc[:, valid_word]#

# %%
a1 = time.perf_counter()
regress=LinearRegression()
regress.fit(tfidf_train, tfidf_score_train)
a2 = time.perf_counter()
a2-a1
# Out:
# 2.4326480543677462

# %%
tfidf_score_predict = regress.predict(tfidf_test)

# %%
mse = np.power((tfidf_score_predict-tfidf_score_test), 2)
# Out:
# 3.9256196237183676e+27

# %%
num = 0
for i in range(len(tfidf_score_predict)):
    a = round(tfidf_score_predict[i])
    if (a-tfidf_score_test[i])<=1:#预测相差2星以内均可接受
        num = num + 1
num
# Out:
# 2896

# %% [markdown]
# #### 寻找大系数

# %%
regress.coef_.argsort()
# Out:
# array([ 346,  240,  228, ...,  175, 1184,  878], dtype=int64)

# %%
regress.coef_[878]
# Out:
# 271477336797395.7

# %%
word[78+275]
# Out:
# 'acts'

# %%
a = abs(hair_score_predict-hair_score_test)
b = np.where(a<0.5, 1, 0)

# %%
hair_test
# Out:
#       marketplace  customer_id       review_id  product_id  product_parent  \
# 10000          US     12278873  R11BYU31X753HA  B000R80ZTQ       486774008
# 10001          US     28535139  R1XJ6KE6T7JUDF  B00092M2X2       221722169
# 10002          US     19524683  R1K18ENMFUKT73  B000R80ZTQ       486774008
# 10003          US     15046220  R2FFUTMXGAXNG5  B0008ENT8I       868768702
# 10004          US     47271222  R3ALV450OKN9JG  B0008ENT8I       868768702
# 10005          US     30719073  R3LCWWNLEKLPYP  B001LF4G7G       236392593
# 10006          US     17204309  R30FVIQ48YROPW  B000A3I2X4       235105995
# 10007          US     45362252  R3JL3FLUMN9F7V  B000FS1W4U       235105995
# 11441                 revlon 1875w volumizing hair dryer           Beauty
# 11442                 conair soft bonnet hair dryer 1 ea           Beauty
# 11443                 conair soft bonnet hair dryer 1 ea           Beauty
# 11444  conair corp pers care 146np conair ionic condi...           Beauty
# 11445  conair corp pers care 146np conair ionic condi...           Beauty
# 11446  conair corp pers care 146np conair ionic condi...           Beauty
# 11447  conair corp pers care 146np conair ionic condi...           Beauty
# 11448  conair corp pers care 146np conair ionic condi...           Beauty
# 11449                 revlon 1875w volumizing hair dryer           Beauty
# 11450  conair corp pers care 146np conair ionic condi...           Beauty
# 11451  conair corp pers care 146np conair ionic condi...           Beauty
# 11452                 revlon 1875w volumizing hair dryer           Beauty
# 11453                 revlon 1875w volumizing hair dryer           Beauty
# 11454                 revlon 1875w volumizing hair dryer           Beauty
# 11455                 revlon 1875w volumizing hair dryer           Beauty
# 11456  conair corp pers care 146np conair ionic condi...           Beauty
# 11457                 revlon 1875w volumizing hair dryer           Beauty
# 11458  conair corp pers care 146np conair ionic condi...           Beauty
# 11459                 revlon 1875w volumizing hair dryer           Beauty
# 11460                 revlon 1875w volumizing hair dryer           Beauty
# 11461  conair corp pers care 146np conair ionic condi...           Beauty
# 11462  conair corp pers care 146np conair ionic condi...           Beauty
# 11463                 revlon 1875w volumizing hair dryer           Beauty
# 11464                 revlon 1875w volumizing hair dryer           Beauty
# 11465                 revlon 1875w volumizing hair dryer           Beauty
# 11466  conair corp pers care 146np conair ionic condi...           Beauty
# 11467  conair corp pers care 146np conair ionic condi...           Beauty
# 11468  conair corp pers care 146np conair ionic condi...           Beauty
# 11469  conair corp pers care 146np conair ionic condi...           Beauty
#
#        star_rating  helpful_votes  total_votes vine verified_purchase  \
# 10000            5              1            1    N                 N
# 10001            4              0            0    N                 N
# 10002            3              0            0    N                 Y
# 10003            1              0            0    N                 Y
# 10004            3              0            0    N                 N
# 10005            5              0            0    N                 Y
# 10006            5             44           49    N                 Y
# 10007            1             32           34    N                 N
# 10008            5              1            1    N                 N
# 10009            5              0            0    N                 Y
# 10010            4             10           13    N                 Y
# 10011            5              0            0    N                 Y
# 10012            5              5            5    N                 Y
# 10013            5              1            1    N                 Y
# 10014            4              1            1    N                 N
# 10015            4              0            0    Y                 N
# 10016            5              1            1    Y                 N
# 10017            4              0            0    N                 Y
# 10018            4              0            1    Y                 N
# 10019            2              1            1    N                 Y
# 10020            5              3            4    Y                 N
# 10021            5              0            0    N                 Y
# 10022            5              0            0    N                 Y
# 10023            1              3            3    N                 Y
# 10024            5              0            0    N                 Y
# 10025            2              2            3    N                 Y
# 10026            4              0            0    N                 N
# 10027            4              3            3    N                 Y
# 10028            5              1            1    N                 Y
# 10029            1             25           33    N                 N
# ...            ...            ...          ...  ...               ...
# 11440            5             15           18    N                 N
# 11441            5              3            3    N                 N
# 11442            1            165          168    N                 Y
# 11443            1             81           83    N                 N
# 11444            5             10           10    N                 N
# 11445            3              5            5    N                 N
# 11446            2              5            6    N                 Y
# 11447            1              6            8    N                 N
# 11448            5            266          281    N                 N
# 11449            5             10           10    N                 N
# 11450            1              4            9    N                 N
# 11451            4              8            9    N                 N
# 11452            5              4            4    N                 N
# 11453            5              6            7    N                 N
# 11454            3              2            2    N                 N
# 11455            5              3            3    N                 N
# 11456            5             13           13    N                 N
# 11457            3              1            6    N                 N
# 11458            4              3            6    N                 N
# 11459            5              4            4    N                 N
# 11460            5              2            5    N                 N
# 11461            4              1            1    N                 N
# 11462            5              3            3    N                 N
# 11463            5             59           61    N                 N
# 11464            4              4            4    N                 N
# 11465            5             14           18    N                 N
# 11466            1             26           32    N                 N
# 11467            5              4            4    N                 Y
# 11468            5             78           87    N                 N
# 11469            3            320          332    N                 Y
#
#                                          review_headline  \
# 10000                                          Fantastic
# 10001                                        Pretty good
# 10002               Dryer Great,,,, Conair, Not So Great
# 10003                                 junk,   zero stars
# 10004                                         Hair Dryer
# 10005                        Remington D-2012 Hair Dryer
# 10006                                          HAIRDRYER
# 10007                                          burns!!!!
# 10008                                      Great Product
# 10009                       Jerdon Wall Mount Hair Dryer
# 10010                             Ok for short thin hair
# 10011                                   Great hair dryer
# 10012                                      Great Product
# 10013                Great hair dryer for the price.....
# 10014                                        Great Dryer
# 10015                                      This is great
# 10016           A superb, solidly constructed hair dryer
# 10017                                It is still working
# 10018  Professional style, but not quality. Decent va...
# 10019      Buy from a place that you can exchange easily
# 10020                                     Fast and quiet
# 10021                                    Nano blow-dryer
# 10022                                         Five Stars
# 10023                                      Disappointing
# 10024         Great hairdryer, slightly heavy, but quiet
# 10025                            My old Conair is better
# 10026                                                 js
# 10027               Lasted 6 weeks, but quickly replaced
# 10028                        Just what i was looking for
# 10029  Warning!!!  Fire may shoot out of cord/handle ...
# ...                                                  ...
# 11440                                 It's worth the $$!
# 11441                           The best blow-dryer ever
# 11442                                  Very Poor Product
# 11443                                  Defective product
# 11444                                          The Best!
# 11445                              Overall; Disappointed
# 11446                                 a Bit Disappointed
# 11447                                    Never again!!!!
# 11448                         New shine for the ol' mane
# 11449                 Move Over Professional Hair Dryers
# 11450                                          it sucks!
# 11451                                         My Ray Gun
# 11452                                       Wonderful!!!
# 11453              As good as the expensive hair dryers!
# 11454                                            It's ok
# 11455                                 Love this Dryer!!!
# 11456                    Great Product for Curly Hair!!!
# 11457                                      Hope it works
# 11458                           Too much electricity use
# 11459                              Absolutely Manificent
# 11460                                          Versatile
# 11461                Best Type of Hair Dryer out there!!
# 11462                                           Good buy
# 11463             Excellent!  Perfect for my thick hair.
# 11464                                   Close to Perfect
# 11465                                        great hair!
# 11466                          Disappointment with dryer
# 11467                                  The best dryer!!!
# 11468                       Excellent for fine/limp hair
# 11469                          Some pluses, some minuses
#
#                                              review_body review_date
# 10000  I know it's an obnoxious color but the bottom ...   1/29/2011
# 10001  I am a Hair Stylist and I was looking for a li...   1/29/2011
# 10002  I have no problems with the hair dryer itself,...   1/27/2011
# 10003  I recieved this hair dryer last night and this...   1/26/2011
# 10004  A long time ago, this dryer was in a favorite ...   1/25/2011
# 10005  A bit heavier than most and cost a little more...   1/25/2011
# 10006  THIS PRODUCT IS AWESOME. I DID NOT REALIZE HOW...   1/25/2011
# 10007  I had this hair dryer for only 3 months before...   1/25/2011
# 10008  I love this blowdryer. I have a lot of thick h...   1/25/2011
# 10009  I am really enjoying the hair dryer and enjoy ...   1/25/2011
# 10010  I have thick hair that is a few inches past my...   1/24/2011
# 10011  First used this product at a hotel in Vegas.  ...   1/21/2011
# 10012  Dryer is lightweight and delivers a lot of hea...   1/21/2011
# 10013  I used this hair dryer while staying at a Marr...   1/21/2011
# 10014  This is a great hair dryer but it dosen't dry ...   1/20/2011
# 10015  Ok, I am not a hair stylist, for that matter i...   1/20/2011
# 10016  This hair dryer is the most powerful I've ever...   1/20/2011
# 10017  It is still working, I like that. I ordered it...   1/20/2011
# 10018  It's styled like a profession hair dryer, but ...   1/19/2011
# 10019  I purchased this as a Christmas present and ho...   1/18/2011
# 10020  This hair dryer works fast to dry hair. It's q...   1/18/2011
# 10021  I love this blow-dryer!  What a great purchase...   1/18/2011
# 10022                                           loved it   1/18/2011
# 10023  I had the same problem as other reviews. After...   1/17/2011
# 10024  I finally realized just how much my tiny trave...   1/16/2011
# 10025  The description is misleading relative to heat...   1/15/2011
# 10026  I needed it right away and bought at Target. T...   1/15/2011
# 10027  Puchased November 2010. I liked this hair drye...   1/15/2011
# 10028  Very happy with my new hair dryer- great for e...   1/15/2011
# 10029  While my wife was using the Elchim Professiona...   1/15/2011
# ...                                                  ...         ...
# 11440  This is an expensive hairdryer, but it dried m...    7/5/2005
# 11441  I never knew how different a blow-dryer could ...    6/5/2005
# 11442  I wish I could have read reviews on this produ...   5/25/2005
# 11443  I bought this hair dryer recently and was tota...   4/13/2005
# 11444  This blowdryer is simply the best. Its cheap a...   11/9/2004
# 11445  Everything works as advertised, however, it di...   11/3/2004
# 11446  The on/off switch on this dryer needs improvem...   8/15/2004
# 11447  I bought this hair dryer a couple of months ag...   5/25/2004
# 11448  As a child of the Sixties, I still wear my hai...   3/15/2004
# 11449  I purchased this dryer for about (a little mon...    3/4/2004
# 11450  I just bought this dryer today after my other ...   1/22/2004
# 11451  I love this dryer, it is sooo quiet.  It dries...    1/6/2004
# 11452  I thought I had a fairly decent blowdryer...un...    4/9/2003
# 11453  I looked at this hair dryer for two reasons: (...    4/2/2003
# 11454  I read these reviews and thought I had found a...   3/31/2003
# 11455  Can you actually love an appliance? B/c this d...   3/11/2003
# 11456  I have very thick, curly hair and recently got...   2/27/2003
# 11457  I just bought this dryer so I have yet to use ...   2/19/2003
# 11458  I bought this hairdryer to get the benefit of ...   1/26/2003
# 11459  I was a little skeptical about the reviews tha...   1/23/2003
# 11460  .<BR>Powerful. Multi-speed, multi-temperature....   1/14/2003
# 11461  I just started using an ionic hairdryer recent...    1/7/2003
# 11462  One of the main reasons why I selected this dr...  12/18/2002
# 11463  I have thick shoulder length hair, that usuall...  12/17/2002
# 11464  Overall, I am extremely pleased with this hair...   11/8/2002
# 11465  I just purchased this dryer, and I really like...   8/21/2002
# 11466  I purchased it because it was supposed to be q...   8/13/2002
# 11467  I love this dryer not only is it QUIET, it rea...   7/13/2002
# 11468  This hairdryer far exceeded my expection for<B...   4/20/2002
# 11469  This is my only experience with an ionic hair ...    3/2/2002
#
# [1470 rows x 15 columns]

# %%
a = np.max(tfidf, axis=1)
b = a.argsort()

# %% [markdown]
# 只保留有情感特征词的tf-idf值构建向量，对于评论中无相应词汇的评论假定对评分无参考，或构建另一套中肯评价体系进行打分；参考文献
# 情绪类评价有较少的赞同反馈，中肯类评价能收到更多反馈

# %%
print(tfidf.shape)
# Out:
# (11470, 12378)

# %%
print(ths.shape)
# Out:
# (11470, 1483)

# %%
print(dropall.shape)
# Out:
# (11470, 1483)

# %%
s = []
for i in range(len(tfidf_score_predict)):
    a = round(tfidf_score_predict[i])
    s.append(a)
pd.DataFrame({'predict':s,
             'real':tfidf_score_test})
# Out:
#            predict  real
# 0     5.000000e+00     5
# 1     4.000000e+00     5
# 2     4.000000e+00     4
# 3     4.000000e+00     3
# 4     1.000000e+00     1
# 5     5.000000e+00     5
# 6     2.000000e+00     3
# 7     5.000000e+00     5
# 8     4.000000e+00     5
# 9     5.000000e+00     5
# 10    4.000000e+00     4
# 11    3.000000e+00     3
# 12    5.000000e+00     5
# 13    3.000000e+00     3
# 14    5.000000e+00     5
# 15    4.000000e+00     5
# 16    5.000000e+00     5
# 17    4.000000e+00     5
# 18    4.000000e+00     4
# 19    4.000000e+00     4
# 20    4.000000e+00     5
# 21    4.000000e+00     5
# 22    5.000000e+00     5
# 23    5.000000e+00     5
# 24    3.000000e+00     3
# 25    4.000000e+00     4
# 26    4.000000e+00     5
# 27    5.000000e+00     5
# 28    4.000000e+00     5
# 29    5.000000e+00     5
# ...            ...   ...
# 3440  4.000000e+00     5
# 3441  5.000000e+00     5
# 3442  4.000000e+00     1
# 3443  4.000000e+00     1
# 3444  5.000000e+00     5
# 3445  2.000000e+00     3
# 3446  5.000000e+00     2
# 3447  1.000000e+00     1
# 3448  2.000000e+00     5
# 3449  4.000000e+00     5
# 3450  4.000000e+00     1
# 3451  4.000000e+00     4
# 3452  3.000000e+00     5
# 3453  4.000000e+00     5
# 3454  4.000000e+00     3
# 3455  5.000000e+00     5
# 3456  4.000000e+00     5
# 3457  4.000000e+00     3
# 3458  3.000000e+00     4
# 3459  4.000000e+00     5
# 3460  4.000000e+00     5
# 3461  4.000000e+00     4
# 3462  2.045427e+12     5
# 3463  5.000000e+00     5
# 3464  3.000000e+00     4
# 3465  3.000000e+00     5
# 3466  4.327654e+11     1
# 3467  5.000000e+00     5
# 3468  4.000000e+00     5
# 3469  6.000000e+00     3
#
# [3470 rows x 2 columns]
